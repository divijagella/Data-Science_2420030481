# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({'Age':[25,30,np.nan,40,35],'Department':['HR','Finance','Finance',np.nan,'IT']})
df['Age'].fillna(df['Age'].mean(),inplace=True)
df['Department'].fillna(df['Department'].mode()[0],inplace=True)
print(df)
# Out:
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2  32.5    Finance
# 3  40.0    Finance
# 4  35.0         IT
# /tmp/ipykernel_2587/2419559501.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(),inplace=True)
# /tmp/ipykernel_2587/2419559501.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Department'].fillna(df['Department'].mode()[0],inplace=True)

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({'Age':[25,30,np.nan,40,35],'Department':['HR','Finance','Finance',np.nan,'IT']})
df_ffill=df.copy()
df_ffill.fillna(method='ffill',inplace=True)
print(df_ffill)
# Out:
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2  30.0    Finance
# 3  40.0    Finance
# 4  35.0         IT
# /tmp/ipykernel_2587/1573230915.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_ffill.fillna(method='ffill',inplace=True)

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({'Age':[25,30,np.nan,40,35],'Department':['HR','Finance','Finance',np.nan,'IT']})
df_bfill=df.copy()
df_bfill.fillna(method='bfill',inplace=True)
print(df_bfill)
# Out:
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2  40.0    Finance
# 3  40.0         IT
# 4  35.0         IT
# /tmp/ipykernel_2587/1508166466.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_bfill.fillna(method='bfill',inplace=True)

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame( {'Age': [25, 30, np.nan, 40, 35],
'Department': ['HR', 'Finance', 'Finance', np.nan, 'IT']})
df_drop_rows = df.dropna()
print("After dropping rows:\n", df_drop_rows)


import pandas as pd
import numpy as np

df = pd.DataFrame({ 'Age': [25, 30, np.nan, 40, 35],
'Department': ['HR', 'Finance', 'Finance', np.nan, 'IT']})
df_drop_cols = df.dropna(axis=1)
print("After dropping columns:\n", df_drop_cols)
# Out:
# After dropping rows:
#      Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 4  35.0         IT
# After dropping columns:
#  Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
import pandas as pd


df = pd.DataFrame({
    'ID': [1, 2, 2, 3, 4, 4],
    'Name': ['Alice', 'Bob', 'Bob', 'Charlie', 'David', 'David'],
    'Age': [25, 30, 30, 35, 40, 40]
})

print("Original Data:\n", df)


df_exact = df.drop_duplicates()
print("\nAfter Exact Match Removal:\n", df_exact)
# Out:
# Original Data:
#     ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 2   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40
# 5   4    David   40
#
# After Exact Match Removal:
#     ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40

# %%
import pandas as pd

df_subset_id = df.drop_duplicates(subset=['ID'])
print("\nAfter Subset-Based Removal (ID):\n", df_subset_id)


df_subset_name = df.drop_duplicates(subset=['Name'])
print("\nAfter Subset-Based Removal (Name):\n", df_subset_name)
# Out:
# After Subset-Based Removal (ID):
#     ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40
#
# After Subset-Based Removal (Name):
#     ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40

# %%
import pandas as pd


df = pd.DataFrame({
    'Date': ['2025-01-05', '05/01/2025', 'Jan 5, 2025', '2025.01.05']
})


df['Date'] = pd.to_datetime(df['Date'], errors='coerce').dt.strftime('%Y-%m-%d')

print(df)
# Out:
#          Date
# 0  2025-01-05
# 1         NaN
# 2         NaN
# 3         NaN

# %%
df = pd.DataFrame({
    'Name': ['Alice', 'BOB', 'charlie', 'DAVID']
})


df['Name_lower'] = df['Name'].str.lower()


df['Name_upper'] = df['Name'].str.upper()

print(df)
# Out:
#       Name Name_lower Name_upper
# 0    Alice      alice      ALICE
# 1      BOB        bob        BOB
# 2  charlie    charlie    CHARLIE
# 3    DAVID      david      DAVID

# %%
# Out:
# Euclidean Distance 3.7416573867739413
# Similarity Distance 0.21089672205953397

# %%
# Out:
# Manhattan Distance 6
# Similarity Manhattan 0.14285714285714285

# %%
# Out:
# Minkowski Distance(p=3): 3.3019272488946263
# Minkowski Similarity(p=3): 0.23245395427292462

# %%
# Out:
# Pearson correlation coefficient: 0.6757341092113647
# P-value: 6.692470646863279e-34

# %%
# Out:
# Spearman Correlation Coefficient: 0.9999999999999999
# P-value: 1.4042654220543672e-24

# %%
# Out:
# Hamming Distance between karolin and kathrin is: None

# %%
# Out:
# Jaccard Index: 0.3333333333333333

# %%
# Out:
# Cosine Similarity: 0.5

# %%
# Out:
# Longest Common Subsequence length between 'ABCDEF' and 'AEBDF': 4

# %%
# Out:
# Objective: Classification: Survived (Yes/No)
# Success Criteria: Accuracy > 80%
# Constraints: Limited features, missing values, imbalanced classes
#
# Dataset Shape: (891, 15)
#
# First 5 Rows:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#
# Data After Preprocessing:
#    survived  pclass   age  sibsp  parch     fare  embark_town alive  \
# 0         0       3  22.0      1      0   7.2500  Southampton    no
# 1         1       1  38.0      1      0  71.2833    Cherbourg   yes
# 2         1       3  26.0      0      0   7.9250  Southampton   yes
# 3         1       1  35.0      1      0  53.1000  Southampton   yes
# 4         0       3  35.0      0      0   8.0500  Southampton    no
#
#    family_size  sex_male  class_Second  class_Third  embarked_Q  embarked_S  \
# 0            1      True         False         True       False        True
# 1            1     False         False        False       False       False
# 2            0     False         False         True       False        True
# 3            1     False         False        False       False        True
# 4            0      True         False         True       False        True
#
#    who_man  who_woman  adult_male_True  alone_True
# 0     True      False             True       False
# 1    False       True            False       False
# 2    False       True            False        True
# 3    False       True            False       False
# 4     True      False             True        True
# ===== Model Evaluation =====
# Accuracy : 0.8193548387096774
# Precision: 0.7758620689655172
# Recall   : 0.75
#
# Confusion Matrix:
# [[82 13]
#  [15 45]]
#
# First 10 Predictions:
# [0 0 0 1 1 1 0 0 0 1]

# %%
# Out:
# Normalized Data (Min-Max Scaling):
#       A     B
# 0  0.00  0.00
# 1  0.25  0.25
# 2  0.50  0.50
# 3  0.75  0.75
# 4  1.00  1.00

# %%
# Out:
# Standardized Data (Z-score):
#           A         B
# 0 -1.414214 -1.414214
# 1 -0.707107 -0.707107
# 2  0.000000  0.000000
# 3  0.707107  0.707107
# 4  1.414214  1.414214

# %%
# Out:
# One-Hot Encoding:
#    Color_Blue  Color_Green  Color_Red
# 0       False        False       True
# 1        True        False      False
# 2       False         True      False
# 3       False        False       True
# 4        True        False      False

# %%
# Out:
# Original Data (first 5 rows):
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
#
# Normalized Data (first 5 rows):
#    total_bill       tip     sex smoker  day    time  size
# 0    0.291579  0.001111  Female     No  Sun  Dinner   0.2
# 1    0.152283  0.073333    Male     No  Sun  Dinner   0.4
# 2    0.375786  0.277778    Male     No  Sun  Dinner   0.4
# 3    0.431713  0.256667    Male     No  Sun  Dinner   0.2
# 4    0.450775  0.290000  Female     No  Sun  Dinner   0.6
#
# Standardized Data (first 5 rows):
#    total_bill       tip     sex smoker  day    time      size
# 0   -0.314711 -1.439947  Female     No  Sun  Dinner -0.600193
# 1   -1.063235 -0.969205    Male     No  Sun  Dinner  0.453383
# 2    0.137780  0.363356    Male     No  Sun  Dinner  0.453383
# 3    0.438315  0.225754    Male     No  Sun  Dinner -0.600193
# 4    0.540745  0.443020  Female     No  Sun  Dinner  1.506958
#
# One-Hot Encoded Data (first 5 rows):
#    total_bill   tip  size  sex_Male  sex_Female  smoker_Yes  smoker_No  \
# 0       16.99  1.01     2     False        True       False       True
# 1       10.34  1.66     3      True       False       False       True
# 2       21.01  3.50     3      True       False       False       True
# 3       23.68  3.31     2      True       False       False       True
# 4       24.59  3.61     4     False        True       False       True
#
#    day_Thur  day_Fri  day_Sat  day_Sun  time_Lunch  time_Dinner
# 0     False    False    False     True       False         True
# 1     False    False    False     True       False         True
# 2     False    False    False     True       False         True
# 3     False    False    False     True       False         True
# 4     False    False    False     True       False         True

# %%
# Out:
# Explained variance ratio: [0.72627656 0.1730423 ]
#
# PCA Result (first 5 rows):
#         PC1       PC2
# 0 -1.348415  0.426746
# 1 -0.955740  1.093576
# 2  0.540971  0.122324
# 3  0.067789 -0.674616
# 4  1.408308  0.847661

# %%
# Out:
# Explained variance ratio: [0.9912126 0.0087874]
#
# LDA Result (first 5 rows):
#         LD1       LD2  target
# 0  8.061800 -0.300421       0
# 1  7.128688  0.786660       0
# 2  7.489828  0.265384       0
# 3  6.813201  0.670631       0
# 4  8.132309 -0.514463       0

# %%
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# t-SNE Result (first 5 rows):
#        TSNE1     TSNE2  target
# 0 -24.284670 -0.196069       0
# 1 -21.731905  0.653882       0
# 2 -21.776773 -0.433848       0
# 3 -21.413086 -0.141203       0
# 4 -24.284908 -0.606254       0

# %%
# Out:
# First 5 rows of dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
# Mean values:
# sepal length (cm)    5.843333
# sepal width (cm)     3.057333
# petal length (cm)    3.758000
# petal width (cm)     1.199333
# dtype: float64
#
# Median values:
# sepal length (cm)    5.80
# sepal width (cm)     3.00
# petal length (cm)    4.35
# petal width (cm)     1.30
# dtype: float64
#
# Mode values:
# sepal length (cm)    5.0
# sepal width (cm)     3.0
# petal length (cm)    1.4
# petal width (cm)     0.2
# Name: 0, dtype: float64

# %%
# Out:
# First 5 rows of dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
# Range values:
# sepal length (cm)    3.6
# sepal width (cm)     2.4
# petal length (cm)    5.9
# petal width (cm)     2.4
# dtype: float64
#
# Variance values:
# sepal length (cm)    0.685694
# sepal width (cm)     0.189979
# petal length (cm)    3.116278
# petal width (cm)     0.581006
# dtype: float64
#
# Standard Deviation values:
# sepal length (cm)    0.828066
# sepal width (cm)     0.435866
# petal length (cm)    1.765298
# petal width (cm)     0.762238
# dtype: float64
#
# Interquartile Range (IQR):
# sepal length (cm)    1.3
# sepal width (cm)     0.5
# petal length (cm)    3.5
# petal width (cm)     1.5
# dtype: float64
